# %%
//%overwritefile
//%file:src/test1.dot
//%log:1
digraph G{
    edge [fontname="FangSong_GB2312"];
    node [ fontname="FangSong_GB2312"];
    {
        main -> parse -> execute;
        main -> init; main -> cleanup;
        execute -> make_string;
        execute -> printf;
        init -> make_string; 
        main -> printf; 
        execute -> 结果; 
    }

}
# Out:
# [MyDotKernel225447] Info:file h:\Jupyter\ipynb\MyDot\src/test1.dot created successfully
# [MyDotKernel225447] Info:The process :h:\Jupyter\ipynb\MyDot\src/test1.dot
